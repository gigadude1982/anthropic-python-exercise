# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
# model = "claude-sonnet-4-5" # middle ground
model = "claude-opus-4-6" # fast and expensive

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_editor":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    # return {
    #     "type": "text_editor_20250728",
    #     "name": "str_replace_based_edit_tool",
    # }
    # TODO: figure out why the 'str_replace_based_edit_tool' won't work with the Anthropic Python SDK
    # it works perfectly fine with cUrl
    if model.startswith("claude-opus-4-6"):
        return {
            "type": "text_editor_20250728",
            "name": "str_replace_based_edit_tool",
            "max_characters": 10000,
        }
    elif model.startswith("claude-sonnet-4-5"):
        return {
            "type": "text_editor_20250728",
            "name": "str_replace_based_edit_tool",
        }
    elif model.startswith("claude-sonnet-3-7"):
        return {
            "type": "text_editor_20250124",
            "name": "str_replace_editor",
        }
    elif model.startswith("claude-sonnet-3-5"):
        return {
            "type": "text_editor_20241022",
            "name": "str_replace_editor",
        }
    else:
        raise ValueError(
            f"Editor tool schema not defined for model {model}. Please update get_text_edit_schema to include the correct schema for this model version."
        )

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./ ./main.py file and write out a function to calculate pi to the 5th digit.
    Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# Let me start by viewing the current state of the repository and the existing `main.py` file.
# Let me try again with the correct tool invocation:
#
# Let me look at the current directory and the main.py file:
# I apologize for the technical difficulties with the tool. Let me try once more:
# I seem to be experiencing a tool connectivity issue. Let me try one more time carefully:
# I apologize for the repeated errors — there seems to be a persistent issue invoking the tool. Let me attempt once more with a slightly different approach:
# I sincerely apologize for the tool issues. Let me provide you with the code directly, and I'll create both files:
# I'm experiencing persistent tool errors. Let me try the absolute minimum call:
# I'm very sorry — the tool system appears to be completely unavailable at the moment. However, here are the two files you need:
#
# ---
#
# ### `./main.py`
#
# ```python
# """Module to calculate pi to the 5th decimal digit."""
#
#
# def calculate_pi(precision=5):
#     """
#     Calculate pi using Machin's formula:
#         pi/4 = 4 * arctan(1/5) - arctan(1/239)
#
#     Args:
#         precision: Number of decimal digits to round to (default 5).
#
#     Returns:
#         A float of pi rounded to `precision` decimal places.
#     """
#
#     def _arctan(x, num_terms=50):
#         """Compute arctan(x) via Taylor series:
#         arctan(x) = x - x^3/3 + x^5/5 - x^7/7 + ..."""
#         result = 0.0
#         for n in range(num_terms):
#             sign = (-1) ** n
#             term = (x ** (2 * n + 1)) / (2 * n + 1)
#             result += sign * term
#         return result
#
#     # Machin's formula: pi = 4 * (4 * arctan(1/5) - arctan(1/239))
#     pi_value = 4.0 * (4.0 * _arctan(1.0 / 5.0) - _arctan(1.0 / 239.0))
#
#     return round(pi_value, precision)
#
#
# if __name__ == "__main__":
#     pi = calculate_pi(5)
#     print(f"Pi to 5 decimal places: {pi}")
# ```
#
# ---
#
# ### `./test.py`
#
# ```python
# """Tests for the calculate_pi function in main.py."""
#
# import unittest
# from main import calculate_pi
#
#
# class TestCalculatePi(unittest.TestCase):
#     """Test suite for calculate_pi."""
#
#     def test_pi_to_5_decimal_places(self):
#         """Pi rounded to 5 decimals should be 3.14159."""
#         self.assertEqual(calculate_pi(5), 3.14159)
#
#     def test_pi_to_0_decimal_places(self):
#         """Pi rounded to 0 decimals should be 3."""
#         self.assertEqual(calculate_pi(0), 3.0)
#
#     def test_pi_to_1_decimal_place(self):
#         """Pi rounded to 1 decimal should be 3.1."""
#         self.assertEqual(calculate_pi(1), 3.1)
#
#     def test_pi_to_2_decimal_places(self):
#         """Pi rounded to 2 decimals should be 3.14."""
#         self.assertEqual(calculate_pi(2), 3.14)
#
#     def test_pi_to_10_decimal_places(self):
#         """Pi rounded to 10 decimals should be 3.1415926536."""
#         self.assertEqual(calculate_pi(10), 3.1415926536)
#
#     def test_return_type_is_float(self):
#         """The return value should be a float."""
#         self.assertIsInstance(calculate_pi(5), float)
#
#     def test_default_precision_is_5(self):
#         """Calling with no arguments should default to 5 decimal places."""
#         self.assertEqual(calculate_pi(), 3.14159)
#
#
# if __name__ == "__main__":
#     unittest.main()
# ```
#
# ---
#
# ### How it works
#
# | Piece | Explanation |
# |---|---|
# | **Algorithm** | Uses **Machin's formula** — `π/4 = 4·arctan(1/5) − arctan(1/239)` — which converges extremely fast (50 Taylor-series terms is more than enough for double-precision). |
# | **`_arctan(x)`** | A helper that evaluates the Taylor series for `arctan(x)`. |
# | **`round(pi_value, precision)`** | Rounds the computed value to the requested number of decimal digits (default 5 → `3.14159`). |
# | **Tests** | Seven `unittest` cases verify
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n    Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='\n\nLet me start by viewing the current state of the repository and the existing `main.py` file.', type='text'),
#    ToolUseBlock(id='toolu_01Pig3TtDrDrnjPKkGpJGf3K', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use'),
#    ToolUseBlock(id='toolu_0151V9jNFs5KWwLZW5xSrLw6', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Pig3TtDrDrnjPKkGpJGf3K',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_0151V9jNFs5KWwLZW5xSrLw6',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me try again with the correct tool invocation:', type='text'),
#    ToolUseBlock(id='toolu_017wLQEyz9Ue7bQVk4YFQgz9', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use'),
#    ToolUseBlock(id='toolu_011YSBuyh1V1uU1d4PRFMYev', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_017wLQEyz9Ue7bQVk4YFQgz9',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_011YSBuyh1V1uU1d4PRFMYev',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01JJF1d2jAYXW3gsdmnYTa64', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/repo'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JJF1d2jAYXW3gsdmnYTa64',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me look at the current directory and the main.py file:', type='text'),
#    ToolUseBlock(id='toolu_01JePfsnG3susrnFdSdkvixz', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JePfsnG3susrnFdSdkvixz',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='I apologize for the technical difficulties with the tool. Let me try once more:', type='text'),
#    ToolUseBlock(id='toolu_01RwqovEQYhsPcjDGW3VN8pz', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01RwqovEQYhsPcjDGW3VN8pz',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='I seem to be experiencing a tool connectivity issue. Let me try one more time carefully:', type='text'),
#    ToolUseBlock(id='toolu_01AYKBh1vv1uCPSfQybkms1Y', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01AYKBh1vv1uCPSfQybkms1Y',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='I apologize for the repeated errors — there seems to be a persistent issue invoking the tool. Let me attempt once more with a slightly different approach:', type='text'),
#    ToolUseBlock(id='toolu_014xY6EVX4MXhzsLfnonY1Pg', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_014xY6EVX4MXhzsLfnonY1Pg',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I sincerely apologize for the tool issues. Let me provide you with the code directly, and I'll create both files:", type='text'),
#    ToolUseBlock(id='toolu_01PQNQepxjVMjYgFT6k3bo7X', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './main.py', 'file_text': '"""Module to calculate pi to the 5th decimal digit."""\n\n\ndef calculate_pi(precision=5):\n    """\n    Calculate pi to the specified number of decimal digits using the\n    Leibniz formula (Gregory-Leibniz series) with enough iterations\n    for convergence, then round to the requested precision.\n\n    The Leibniz series:  pi/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\n\n    For better convergence we use the Machin-like formula:\n        pi/4 = 4 * arctan(1/5) - arctan(1/239)\n\n    Args:\n        precision: Number of decimal digits to round to (default 5).\n\n    Returns:\n        A float representation of pi rounded to `precision` decimal places.\n    """\n\n    def _arctan(x, num_terms=50):\n        """Compute arctan(x) using the Taylor series expansion:\n        arctan(x) = x - x^3/3 + x^5/5 - x^7/7 + ..."""\n        result = 0.0\n        for n in range(num_terms):\n            sign = (-1) ** n\n            term = (x ** (2 * n + 1)) / (2 * n + 1)\n            result += sign * term\n        return result\n\n    # Machin\'s formula: pi = 4 * (4 * arctan(1/5) - arctan(1/239))\n    pi_value = 4.0 * (4.0 * _arctan(1.0 / 5.0) - _arctan(1.0 / 239.0))\n\n    return round(pi_value, precision)\n\n\nif __name__ == "__main__":\n    pi = calculate_pi(5)\n    print(f"Pi to 5 decimal places: {pi}")\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01PQNQepxjVMjYgFT6k3bo7X',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'm experiencing persistent tool errors. Let me try the absolute minimum call:", type='text'),
#    ToolUseBlock(id='toolu_01GqrBmqJq8SEdyK8rvJYBok', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01GqrBmqJq8SEdyK8rvJYBok',
#     'content': 'Error: Unknown tool name: str_replace_based_edit_tool',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='I\'m very sorry — the tool system appears to be completely unavailable at the moment. However, here are the two files you need:\n\n---\n\n### `./main.py`\n\n```python\n"""Module to calculate pi to the 5th decimal digit."""\n\n\ndef calculate_pi(precision=5):\n    """\n    Calculate pi using Machin\'s formula:\n        pi/4 = 4 * arctan(1/5) - arctan(1/239)\n\n    Args:\n        precision: Number of decimal digits to round to (default 5).\n\n    Returns:\n        A float of pi rounded to `precision` decimal places.\n    """\n\n    def _arctan(x, num_terms=50):\n        """Compute arctan(x) via Taylor series:\n        arctan(x) = x - x^3/3 + x^5/5 - x^7/7 + ..."""\n        result = 0.0\n        for n in range(num_terms):\n            sign = (-1) ** n\n            term = (x ** (2 * n + 1)) / (2 * n + 1)\n            result += sign * term\n        return result\n\n    # Machin\'s formula: pi = 4 * (4 * arctan(1/5) - arctan(1/239))\n    pi_value = 4.0 * (4.0 * _arctan(1.0 / 5.0) - _arctan(1.0 / 239.0))\n\n    return round(pi_value, precision)\n\n\nif __name__ == "__main__":\n    pi = calculate_pi(5)\n    print(f"Pi to 5 decimal places: {pi}")\n```\n\n---\n\n### `./test.py`\n\n```python\n"""Tests for the calculate_pi function in main.py."""\n\nimport unittest\nfrom main import calculate_pi\n\n\nclass TestCalculatePi(unittest.TestCase):\n    """Test suite for calculate_pi."""\n\n    def test_pi_to_5_decimal_places(self):\n        """Pi rounded to 5 decimals should be 3.14159."""\n        self.assertEqual(calculate_pi(5), 3.14159)\n\n    def test_pi_to_0_decimal_places(self):\n        """Pi rounded to 0 decimals should be 3."""\n        self.assertEqual(calculate_pi(0), 3.0)\n\n    def test_pi_to_1_decimal_place(self):\n        """Pi rounded to 1 decimal should be 3.1."""\n        self.assertEqual(calculate_pi(1), 3.1)\n\n    def test_pi_to_2_decimal_places(self):\n        """Pi rounded to 2 decimals should be 3.14."""\n        self.assertEqual(calculate_pi(2), 3.14)\n\n    def test_pi_to_10_decimal_places(self):\n        """Pi rounded to 10 decimals should be 3.1415926536."""\n        self.assertEqual(calculate_pi(10), 3.1415926536)\n\n    def test_return_type_is_float(self):\n        """The return value should be a float."""\n        self.assertIsInstance(calculate_pi(5), float)\n\n    def test_default_precision_is_5(self):\n        """Calling with no arguments should default to 5 decimal places."""\n        self.assertEqual(calculate_pi(), 3.14159)\n\n\nif __name__ == "__main__":\n    unittest.main()\n```\n\n---\n\n### How it works\n\n| Piece | Explanation |\n|---|---|\n| **Algorithm** | Uses **Machin\'s formula** — `π/4 = 4·arctan(1/5) − arctan(1/239)` — which converges extremely fast (50 Taylor-series terms is more than enough for double-precision). |\n| **`_arctan(x)`** | A helper that evaluates the Taylor series for `arctan(x)`. |\n| **`round(pi_value, precision)`** | Rounds the computed value to the requested number of decimal digits (default 5 → `3.14159`). |\n| **Tests** | Seven `unittest` cases verify', type='text')]}]
